# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
url = "https://github.com/chrisc617/Data-Bootcamp-Final-Project/raw/master/NYC_crime.csv"
cd = pd.read_csv(url, header = 0)
cd
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0      509240632     1/1/2016     12:00:00     8/8/2017     12:00:00
# 1      418016737     1/1/2016      1:10:00          NaN          NaN
# 2      404890055     1/1/2016      0:01:00   12/31/2016     23:59:00
# 3      156095250     1/1/2016     12:00:00   12/31/2016     12:00:00
# 4      190783666     1/1/2016     12:00:00    3/10/2017     10:00:00
# 5      621425183     1/1/2016     10:00:00    2/26/2017     17:00:00
# 6      479509422     1/1/2016      0:01:00   12/31/2016     23:59:00
# 7      631892474     1/1/2016      0:00:00     2/7/2017      0:00:00
# 8      885539002     1/1/2016     10:00:00    1/29/2017     12:02:00
# 9      841999126     1/1/2016      0:01:00     1/1/2016     23:59:00
# 10     917205874     1/1/2016     21:30:00     1/2/2017     21:30:00
# 11     738303838     1/2/2016     18:55:00          NaN          NaN
# 12     938580208     1/3/2016      0:00:00     4/4/2017     12:25:00
# ...

# %%
cd.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD            int64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# PARKS_NM              object
# HADEVELOPT            object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# dtype: object

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# %%
cd1 = cd.copy()
cd1.drop(['PARKS_NM','ADDR_PCT_CD','JURIS_DESC','HADEVELOPT','PD_DESC','PD_CD','KY_CD'], axis=1)
cd1
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0      509240632     1/1/2016     12:00:00     8/8/2017     12:00:00
# 1      418016737     1/1/2016      1:10:00          NaN          NaN
# 2      404890055     1/1/2016      0:01:00   12/31/2016     23:59:00
# 3      156095250     1/1/2016     12:00:00   12/31/2016     12:00:00
# 4      190783666     1/1/2016     12:00:00    3/10/2017     10:00:00
# 5      621425183     1/1/2016     10:00:00    2/26/2017     17:00:00
# 6      479509422     1/1/2016      0:01:00   12/31/2016     23:59:00
# 7      631892474     1/1/2016      0:00:00     2/7/2017      0:00:00
# 8      885539002     1/1/2016     10:00:00    1/29/2017     12:02:00
# 9      841999126     1/1/2016      0:01:00     1/1/2016     23:59:00
# 10     917205874     1/1/2016     21:30:00     1/2/2017     21:30:00
# 11     738303838     1/2/2016     18:55:00          NaN          NaN
# 12     938580208     1/3/2016      0:00:00     4/4/2017     12:25:00
# ...

# %%
# from pygeocoder import Geocoder
# cd1[address] = Geocoder.reverse_geocode(cd1[Latitude][0], cd1['Longitude'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1c864f2a6d92> in <module>()
#       1 from pygeocoder import Geocoder
# ----> 2 cd1[address] = Geocoder.reverse_geocode(cd1[Latitude][0], cd1['Longitude'][0])
#
# NameError: name 'Latitude' is not defined

# %%
cd1['Latitude'][1]
# Out:
# 40.739877659999998

# %%
locstr = str(cd1['Latitude'][1]) +","+ str(cd1['Longitude'][1])
locstr
type(locstr)
# Out:
# str

# %%
z = geolocator.reverse(cd1['Latitude'][1], cd1['Longitude'][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-337aa76a8269> in <module>()
#       1 z = geolocator.reverse(locstr)
# ----> 2 z.split
#
# AttributeError: 'Location' object has no attribute 'split'

# %%
type(z.raw)
z.raw
# Out:
# {'address': {'city': 'NYC',
#   'country': 'United States of America',
#   'country_code': 'us',
#   'county': 'New York County',
#   'house_number': '133',
#   'neighbourhood': 'Chelsea',
#   'postcode': '10011',
#   'road': 'West 17th Street',
#   'state': 'New York'},
#  'boundingbox': ['40.7398405', '40.740152', '-73.9968487', '-73.9964457'],
#  'display_name': '133, West 17th Street, Chelsea, Manhattan Community Board 4, New York County, NYC, New York, 10011, United States of America',
#  'lat': '40.740018',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#  'lon': '-73.9966390637207',
#  'osm_id': '264644777',
#  'osm_type': 'way',
#  'place_id': '131288524'}

# %%
type(z.raw)
# Out:
# dict

# %%
print(z.raw.get('address').get('postcode'))
# Out:
# 10011

# %%
ziploc = []
for i, rows in cd1.head(2).iterrows():
    locstr = str(cd1['Latitude'][i]) +","+ str(cd1['Longitude'][i])
    locstr
    geoloc = geolocator.reverse(locstr)
    ziploc.append(geoloc.raw.get('address').get('postcode'))
cd1['zip']=ziploc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-00dcbe652864> in <module>()
#       5     geoloc = geolocator.reverse(locstr)
#       6     ziploc.append(geoloc.raw.get('address').get('postcode'))
# ----> 7 cd1['zip']=ziploc
#
# C:\Users\Ashu\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# C:\Users\Ashu\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# ...

# %%
ziploc
# Out:
# ['10075', '10011']
